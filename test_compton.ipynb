# %%
using DrWatson

@quickactivate :QEDprobing

# %%
using QEDbase
using QEDprocesses
using BenchmarkTools

# %%
model = PerturbativeQED()
proc = Compton(PolX())
@show proc
ps_def = PhasespaceDefinition(SphericalCoordinateSystem(),ElectronRestFrame())
in_ps = [1.0]
out_ps = [0.3,0.0]
# Out:
# proc = Compton{AllSpin, PolarizationX, AllSpin, AllPolarization}(AllSpin(), PolX()
# , AllSpin(), AllPol()
# )
# 2-element Vector{Float64}:
#  0.3
#  0.0

# %%
differential_cross_section(proc,model,ps_def,in_ps,ps_def,out_ps)
# Out:
# 4.313869143542741e-6

# %%
@benchmark differential_cross_section($proc,$model,$ps_def,$in_ps,$ps_def,$out_ps)
# Out:
# BenchmarkTools.Trial: 10000 samples with 9 evaluations.
#  Range (min … max):  2.588 μs … 151.296 μs  ┊ GC (min … max): 0.00% … 96.06%
#  Time  (median):     2.685 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   2.739 μs ±   1.496 μs  ┊ GC (mean ± σ):  0.53% ±  0.96%
#
#       ▃▆▇███▆▃▁
#   ▁▂▃▇█████████▇▇█▇█▇▄▆▅▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▃
#   2.59 μs         Histogram: frequency by time        3.12 μs <
#
#  Memory estimate: 528 bytes, allocs estimate: 3.

# %%
om = 1.0
cth = 0.3
sth = sqrt(1-cth^2)
phi = 0.0
sphi,cphi = sincos(phi)

K = SFourMomentum(1.0,0,0,1.0)
P = SFourMomentum(1.0,0,0,0)

omp = om/(1+om*(1-cth))
Kp = SFourMomentum(omp,omp*sth*cphi,omp*sth*sphi,omp*cth)
Pp = P+K-Kp
# Out:
# 4-element SFourMomentum with indices SOneTo(4):
#   1.4117647058823528
#  -0.5611407067158504
#   0.0
#   0.8235294117647058

# %%
in_moms = [P,K]
out_moms = [Pp,Kp]

differential_cross_section(proc,model,ps_def,in_moms,ps_def,out_moms)
# Out:
# 1.2697732918744528e-5

# %%
@benchmark QEDprocesses._unsafe_differential_cross_section($proc,$model,$ps_def,$in_moms,$ps_def,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 9 evaluations.
#  Range (min … max):  2.616 μs …   4.764 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     2.708 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   2.738 μs ± 115.660 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#         ▅▇██▇ ▃
#   ▂▂▂▃▄████████▇▅▄▄▅▅▅▅▅▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▂▂ ▃
#   2.62 μs         Histogram: frequency by time        3.14 μs <
#
#  Memory estimate: 528 bytes, allocs estimate: 3.

# %%
@benchmark QEDprocesses._matrix_element($proc,$model,$in_moms,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 9 evaluations.
#  Range (min … max):  2.523 μs …   7.130 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     2.593 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   2.631 μs ± 139.441 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#       ▃▆██▄
#   ▁▂▄▇█████▇▃▃▃▅▆▆▅▄▃▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▂
#   2.52 μs         Histogram: frequency by time        3.06 μs <
#
#  Memory estimate: 336 bytes, allocs estimate: 2.

# %%
@benchmark QEDprocesses._phase_space_factor($proc,$model,$ps_def,$in_moms,$ps_def,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1000 evaluations.
#  Range (min … max):  1.833 ns … 12.209 ns  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     1.917 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.944 ns ±  0.191 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#          ▇      █      █      ▅       ▃      ▂      ▁      ▂ ▂
#   █▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁█ █
#   1.83 ns      Histogram: log(frequency) by time     2.17 ns <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
@benchmark QEDprocesses._averaging_norm($proc)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1000 evaluations.
#  Range (min … max):  0.916 ns … 10.833 ns  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     0.959 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   0.982 ns ±  0.127 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#              █           ▇          ▃           ▁            ▁
#   █▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█ █
#   0.916 ns     Histogram: log(frequency) by time     1.12 ns <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
@benchmark QEDprocesses._incident_flux($proc,$model,$in_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1000 evaluations.
#  Range (min … max):  4.291 ns … 14.875 ns  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     4.459 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   4.475 ns ±  0.224 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#      ▆  █   ▅  ▆   █  ▃  ▂   ▄  ▄   ▁  ▁  ▁                  ▂
#   █▁▁█▁▁█▁▁▁█▁▁█▁▁▁█▁▁█▁▁█▁▁▁█▁▁█▁▁▁█▁▁█▁▁█▁▁▁█▁▁█▁▁▁█▁▁▆▁▁▄ █
#   4.29 ns      Histogram: log(frequency) by time        5 ns <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
@benchmark QEDprocesses._all_onshell($proc,$in_moms,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 972 evaluations.
#  Range (min … max):  75.403 ns …  1.262 μs  ┊ GC (min … max): 0.00% … 90.09%
#  Time  (median):     76.646 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   80.858 ns ± 61.098 ns  ┊ GC (mean ± σ):  4.25% ±  5.23%
#
#   ▁▅▆▇▇██▇▅▅▄▄▄▄▃▂▂▂▂▂▂▁▁      ▁▁▂▁▁                          ▂
#   █████████████████████████▇▆██████████▇█▇▆▆▆▆▅▇▇▆▆▇▆▇▇▅▅▆▄▅▅ █
#   75.4 ns      Histogram: log(frequency) by time      86.9 ns <
#
#  Memory estimate: 160 bytes, allocs estimate: 2.

# %%
@benchmark QEDprocesses._is_in_phasespace($proc,$model,$ps_def,$in_moms,$ps_def,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 891 evaluations.
#  Range (min … max):  123.316 ns …  1.456 μs  ┊ GC (min … max): 0.00% … 88.62%
#  Time  (median):     136.130 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   140.585 ns ± 67.413 ns  ┊ GC (mean ± σ):  2.60% ±  4.87%
#
#             ▁▁▂▃▃▆▅▅▆█▇█▆▇▇▅▅▆▅▄▄▃▁▂▂▂▁
#   ▁▁▁▂▂▃▄▆▆████████████████████████████▇▇▇▇▆▅▆▄▄▄▄▃▂▃▂▂▂▂▂▂▁▁▁ ▅
#   123 ns          Histogram: frequency by time          155 ns <
#
#  Memory estimate: 160 bytes, allocs estimate: 2.

# %%
function _compton_matrix_element_square_spinsum_polsum(in_ps,out_ps)
    pre_fac = 8*ELEMENTARY_CHARGE^4
    pk = prod(in_ps)
    pkp=in_ps[1]*out_ps[2]

    pkp_over_pk = pkp/pk
    term = 1.0/(pk) - 1.0/pkp

    return pre_fac*(pkp_over_pk + 1.0/pkp_over_pk + 2*term + term^2)
end
# Out:
# _compton_matrix_element_square_spinsum_polsum (generic function with 1 method)

# %%
@benchmark _compton_matrix_element_square_spinsum_polsum($in_moms,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1000 evaluations.
#  Range (min … max):  6.458 ns … 20.125 ns  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     6.667 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   6.719 ns ±  0.289 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#     ▃  ▇  ▃  ▄ █  ▆  █  ▄ ▃  ▃  ▂  ▄ ▂  ▁  ▁                 ▂
#   ▄▁█▁▁█▁▁█▁▁█▁█▁▁█▁▁█▁▁█▁█▁▁█▁▁█▁▁█▁█▁▁█▁▁█▁▁█▁▇▁▁█▁▁█▁▁█▁▆ █
#   6.46 ns      Histogram: log(frequency) by time     7.33 ns <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
@benchmark sum(QEDprocesses._matrix_element_square($proc,$model,$in_moms,$out_moms))
# Out:
# BenchmarkTools.Trial: 10000 samples with 9 evaluations.
#  Range (min … max):  2.602 μs …   8.269 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     2.741 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   2.758 μs ± 169.315 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#       ▂▅▇▄    ▄▇█▇▄
#   ▁▂▄▆█████▅▇███████▆▆▄▄▅▆▆▆▅▅▃▄▂▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▃
#   2.6 μs          Histogram: frequency by time        3.18 μs <
#
#  Memory estimate: 528 bytes, allocs estimate: 3.

# %%
function _matrix_element_square_summed(
    proc::Compton,
    model::AbstractModelDefinition,
    in_phase_space::AbstractVector{T},
    out_phase_space::AbstractVector{T},
) where {T<:QEDbase.AbstractFourMomentum}

    return sum(QEDprocesses._matrix_element_square(proc,model,in_phase_space,out_phase_space))
end

function _matrix_element_square_summed(
    proc::Compton{AllSpin, AllPolarization, AllSpin, AllPolarization},
    model::PerturbativeQED,
    in_phase_space::AbstractVector{T},
    out_phase_space::AbstractVector{T},
) where {T<:QEDbase.AbstractFourMomentum}

    return _compton_matrix_element_square_spinsum_polsum(in_phase_space,out_phase_space)
end

function QEDprocesses._unsafe_differential_probability(
    proc::Compton,
    model::AbstractModelDefinition,
    in_phase_space_def::AbstractPhasespaceDefinition,
    in_phase_space::AbstractVector{T},
    out_phase_space_def::AbstractPhasespaceDefinition,
    out_phase_space::AbstractVector{T},
) where {T<:QEDbase.AbstractFourMomentum}
    matrix_elements_sq_summed = _matrix_element_square_summed(
        proc, model, in_phase_space, out_phase_space
    )

    normalization = QEDprocesses._averaging_norm(proc)

    ps_fac = QEDprocesses._phase_space_factor(
        proc,
        model,
        in_phase_space_def,
        in_phase_space,
        out_phase_space_def,
        out_phase_space,
    )

    return normalization * matrix_elements_sq_summed * ps_fac
end

# %%
differential_cross_section(proc,model,ps_def,in_moms,ps_def,out_moms)
# Out:
# 1.2697732918744533e-5

# %%
@benchmark differential_cross_section($proc,$model,$ps_def,$in_moms,$ps_def,$out_moms)
# Out:
# BenchmarkTools.Trial: 10000 samples with 671 evaluations.
#  Range (min … max):  186.787 ns …  1.913 μs  ┊ GC (min … max): 0.00% … 86.12%
#  Time  (median):     207.836 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   213.807 ns ± 74.910 ns  ┊ GC (mean ± σ):  1.62% ±  4.11%
#
#              ▂▄▄▆▆▇▇▇▆█▅▅▆▃▃▃▁▁
#   ▁▁▁▂▂▃▄▅▆▇███████████████████▇█▇▇▇▇▇█▇▆▇▇▆▇▆▆▅▃▄▄▄▃▃▃▃▂▂▂▂▂▁ ▅
#   187 ns          Histogram: frequency by time          241 ns <
#
#  Memory estimate: 160 bytes, allocs estimate: 2.
